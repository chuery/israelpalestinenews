# %%
import requests
import pandas as pd
import time  # For adding delay between requests

# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'israel',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 5  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

            print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df = pd.DataFrame(articles, columns=['Date', 'Headline'])

# Print the first 5 rows of the DataFrame
print(df.head())

# Optionally, save the DataFrame to a CSV file
# df.to_csv('guardian_articles.csv', index=False)
# Out:
# Fetched 200 articles from page 1
# Fetched 200 articles from page 2
# Fetched 200 articles from page 3
# Fetched 200 articles from page 4
# Fetched 200 articles from page 5
#                                                 Date              Headline
# 0  Tackling the Israel-Palestine conflict in scho...  2025-01-23T17:52:35Z
# 1  Israel strikes targets in southern Syria after...  2025-02-25T23:50:18Z
# 2  Netanyahu says ‘whoever harms Israel will pay ...  2024-12-19T17:56:04Z
# 3  Sydney writers’ festival chair resigns amid de...  2025-02-25T01:52:16Z
# 4  Giller prize drops sponsor after protests over...  2025-02-04T15:27:23Z

# %%
df
# Out:
#                                                   Date              Headline
# 0    Tackling the Israel-Palestine conflict in scho...  2025-01-23T17:52:35Z
# 1    Israel strikes targets in southern Syria after...  2025-02-25T23:50:18Z
# 2    Netanyahu says ‘whoever harms Israel will pay ...  2024-12-19T17:56:04Z
# 3    Sydney writers’ festival chair resigns amid de...  2025-02-25T01:52:16Z
# 4    Giller prize drops sponsor after protests over...  2025-02-04T15:27:23Z
# ..                                                 ...                   ...
# 995  Iran and Israel playing with fire as old rules...  2024-04-19T07:56:40Z
# 996  Charity Commission to review blogpost by Campa...  2024-11-15T12:52:35Z
# 997  More than 160 Gazan medics held in Israeli pri...  2025-02-25T05:00:30Z
# 998  Contempt for human rights, trashing allies: th...  2024-11-09T17:00:54Z
# 999  ‘Famine is setting in’: UN court orders Israel...  2024-03-28T23:01:10Z
#
# [1000 rows x 2 columns]

# %%
from google.colab import files
df.to_csv("guardian_israel.csv")
files.download('guardian_israel.csv')

# %%
# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'israel palestine',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 5  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

          #  print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df_israel_palestine = pd.DataFrame(articles, columns=['Date', 'Headline'])

df_israel_palestine
# Out:
#                                                   Date              Headline
# 0    Tackling the Israel-Palestine conflict in scho...  2025-01-23T17:52:35Z
# 1    Sydney writers’ festival chair resigns amid de...  2025-02-25T01:52:16Z
# 2    Australia’s pro-Palestine movement shifts focu...  2025-01-21T03:47:32Z
# 3    ‘A whole new world opened up’: the radical pro...  2024-12-14T13:11:07Z
# 4    No Other Land review – powerful Israel-Palesti...  2024-09-30T20:28:49Z
# ..                                                 ...                   ...
# 995  ICC prosecutor to face external investigation ...  2024-11-11T19:44:18Z
# 996  How pervasive is antisemitism on US campuses? ...  2024-05-03T17:00:55Z
# 997  Guardian Essential poll: more than half of Aus...  2024-10-08T02:45:03Z
# 998  Revealed: repairing Israel’s destruction of Ga...  2024-06-06T07:01:19Z
# 999  Israel reportedly kills senior Hezbollah comma...  2024-07-03T15:44:20Z
#
# [1000 rows x 2 columns]

# %%
df_israel_palestine.to_csv("guardian_israel_palestine.csv")
files.download('guardian_israel_palestine.csv')

# %%
# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'gaza',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 10  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

          #  print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df_gaza = pd.DataFrame(articles, columns=['Date', 'Headline'])

df_gaza
# Out:
#                                                    Date              Headline
# 0           Donald Trump’s Gaza plan: the key takeaways  2025-02-05T02:15:24Z
# 1     Israeli military withdraws from Netzarim corri...  2025-02-09T17:01:02Z
# 2              Gaza ceasefire deal: what we know so far  2025-01-15T22:55:00Z
# 3     Netanyahu ‘committed’ to Trump’s plan to take ...  2025-02-17T17:34:26Z
# 4     Trump’s grotesque Gaza proposal is appalling o...  2025-02-06T07:00:05Z
# ...                                                 ...                   ...
# 1995  Keir Starmer joins Rishi Sunak in calling for ...  2023-12-18T18:04:23Z
# 1996  Rishi Sunak presses for restoration of water s...  2023-10-22T09:59:44Z
# 1997  AFP boss questioned about PM’s knowledge of Du...  2025-02-06T06:39:20Z
# 1998  Threat to stock markets comes from China and M...  2024-08-11T10:12:40Z
# 1999     Who is the Hamas military chief Mohammed Deif?  2024-07-13T17:59:56Z
#
# [2000 rows x 2 columns]

# %%
df_gaza.to_csv("guardian_gaza.csv")
files.download('guardian_gaza.csv')

# %%
# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'israel',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 10  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

          #  print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df_israel = pd.DataFrame(articles, columns=['Date', 'Headline'])

df_israel
# Out:
#                                                    Date              Headline
# 0     Tackling the Israel-Palestine conflict in scho...  2025-01-23T17:52:35Z
# 1     Israel strikes targets in southern Syria after...  2025-02-25T23:50:18Z
# 2     Netanyahu says ‘whoever harms Israel will pay ...  2024-12-19T17:56:04Z
# 3     Sydney writers’ festival chair resigns amid de...  2025-02-25T01:52:16Z
# 4     Giller prize drops sponsor after protests over...  2025-02-04T15:27:23Z
# ...                                                 ...                   ...
# 1995  Israelis displaced by war split over prospect ...  2024-11-25T18:46:38Z
# 1996  Middle East crisis: World Health Organization ...  2024-02-14T15:16:31Z
# 1997  Death toll in Lebanon walkie-talkie explosions...  2024-09-18T22:06:08Z
# 1998  Labour councillors quit party in protest at Ke...  2023-10-16T18:28:36Z
# 1999  Starmer writes to Labour councillors amid crit...  2023-10-18T18:31:59Z
#
# [2000 rows x 2 columns]

# %%
# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'palestine',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 5  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

          #  print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df_palestine = pd.DataFrame(articles, columns=['Date', 'Headline'])

df_palestine
# Out:
#                                                   Date              Headline
# 0    Tackling the Israel-Palestine conflict in scho...  2025-01-23T17:52:35Z
# 1    NHS staff barred from workplace for considerin...  2025-02-09T16:00:04Z
# 2    ‘Waterfront property’: what are Trump’s real e...  2025-02-05T18:27:56Z
# 3    Sydney writers’ festival chair resigns amid de...  2025-02-25T01:52:16Z
# 4    Met bans pro-Palestine march from gathering ou...  2025-01-09T20:44:04Z
# ..                                                 ...                   ...
# 995  Fifteen months of Israeli bombardment leave co...  2025-01-13T20:01:17Z
# 996  Meet the Israeli Rabbi and survivor of 7 Octob...  2024-04-01T14:00:09Z
# 997  More transparency needed on exports to Israel ...  2024-06-09T15:00:21Z
# 998  Middle East crisis live: Israeli airstrike kil...  2024-11-07T19:59:26Z
# 999  France carried out bombing raid on Islamic Sta...  2024-12-31T12:55:37Z
#
# [1000 rows x 2 columns]

# %%
df_palestine.to_csv("guardian_palestine.csv")
files.download('guardian_palestine.csv')

# %%
# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'palestinians',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 5  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

          #  print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df_palestinians = pd.DataFrame(articles, columns=['Date', 'Headline'])

df_palestinians
# Out:
#                                                   Date              Headline
# 0    ‘International Law’ is an illusion for Palesti...  2024-12-12T11:20:15Z
# 1    Gaunt Israelis and Palestinians freed under fi...  2025-02-09T12:28:23Z
# 2    ‘My arrest was unjustified’: released Palestin...  2025-01-20T20:18:01Z
# 3    UK disagrees with Trump’s proposals for US tak...  2025-02-05T13:21:18Z
# 4    Trump says Palestinians have ‘no alternative’ ...  2025-02-04T21:22:53Z
# ..                                                 ...                   ...
# 995  Biden and Netanyahu speak as pressure grows ov...  2024-04-29T00:38:15Z
# 996  The focus must be on breaking the cycle of vio...  2024-08-17T17:00:04Z
# 997  Middle East crisis: Israeli forces ‘fired on W...  2025-01-06T15:51:38Z
# 998  Israel mulls using private security contractor...  2024-10-22T18:25:54Z
# 999  Senator demands answers on reports of Meta cen...  2023-12-15T06:00:19Z
#
# [1000 rows x 2 columns]

# %%
df_palestinians.to_csv("guardian_palestinians.csv")
files.download('guardian_palestinians.csv')

# %%
# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'hamas',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 11  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

          #  print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df_hamas = pd.DataFrame(articles, columns=['Date', 'Headline'])

df_hamas
# Out:
#                                                    Date              Headline
# 0     Israeli cabinet ratifies ceasefire deal with H...  2025-01-17T23:30:10Z
# 1     Egypt draws up Gaza reconstruction plan that w...  2025-02-16T17:44:46Z
# 2     Hamas suspends release of Israeli hostages ove...  2025-02-10T20:53:47Z
# 3     Hamas faces hard choice over next hostage rele...  2025-02-12T16:55:41Z
# 4     Amid the ceasefire wrangling, how popular is H...  2025-02-11T16:35:14Z
# ...                                                 ...                   ...
# 2195  Questions of identity and safety for Muslims a...  2024-10-09T17:01:39Z
# 2196  Democrats rally to Biden’s defense over respon...  2024-05-05T19:59:22Z
# 2197  Gaza ceasefire to begin on Friday morning with...  2023-11-23T15:30:07Z
# 2198  Trump secretly gave Putin Covid test machines,...  2024-10-08T16:30:34Z
# 2199  Middle East crisis live: ‘Extraordinary’ chanc...  2024-02-17T16:00:31Z
#
# [2200 rows x 2 columns]

# %%
df_hamas.to_csv("guardian_hamas.csv")
files.download('guardian_hamas.csv')

# %%
# Set your API key here
API_KEY = 'e0e11527-a292-4f44-ae54-44e05c6f72fc'

# Base URL for The Guardian search API
BASE_URL = 'https://content.guardianapis.com/search'

# Parameters for the API request
params = {
    'q': 'idf',  # Search term
    'from-date': '2023-10-01',  # Start date
    'to-date': '2025-02-28',    # End date
    'api-key': API_KEY,          # Your API key
    'page-size': 200,            # Number of articles per page (max 200)
    'show-fields': 'webTitle,webPublicationDate',  # Request only the headline and publication date
}

def fetch_articles():
    all_articles = []
    pages = 5  # Total pages to fetch to get 1000 articles (200 per page)

    for page in range(1, pages + 1):
        # Add the page number to the parameters
        params['page'] = page

        # Make the API request
        response = requests.get(BASE_URL, params=params)

        # If the request was successful, process the data
        if response.status_code == 200:
            data = response.json()
            articles = data['response']['results']

            # Extract headlines and publication dates
            for article in articles:
                headline = article['webTitle']
                pub_date = article['webPublicationDate']
                all_articles.append([headline, pub_date])  # Store each article's headline and publication date

          #  print(f'Fetched {len(articles)} articles from page {page}')

            # Add a delay of 1 second before making the next request
            time.sleep(1)  # Adjust this as needed
        else:
            print(f'Failed to fetch data from page {page}')
            break

    return all_articles

# Fetch the articles
articles = fetch_articles()

# Convert the list of articles into a Pandas DataFrame
df_idf = pd.DataFrame(articles, columns=['Date', 'Headline'])

df_idf
# Out:
#                                                   Date              Headline
# 0    IDF soldiers on leave among New Orleans truck ...  2025-01-11T00:01:47Z
# 1    Israeli forces to remain in Lebanon after Tues...  2025-02-17T15:57:37Z
# 2    IDF distances itself from ‘no return’ remarks ...  2024-11-07T13:53:38Z
# 3    Hundreds flee north Gaza as IDF orders more ev...  2024-11-24T19:01:24Z
# 4    IDF strikes military sites in Iran: what we kn...  2024-10-26T12:12:12Z
# ..                                                 ...                   ...
# 995  Labour MPs fear for safety as pro-Palestine pr...  2023-11-17T18:39:11Z
# 996  More than 60 arrests in Amsterdam after attack...  2024-11-08T15:51:56Z
# 997  Isolated at home and abroad, but Netanyahu isn...  2024-04-07T07:00:23Z
# 998    Israel and Hamas at war: what we know on day 26  2023-11-01T20:52:12Z
# 999  Washington faces UN showdown over fresh resolu...  2023-12-07T12:08:47Z
#
# [1000 rows x 2 columns]

# %%
df_idf.to_csv("guardian_idf.csv")
files.download('guardian_idf.csv')

# %%
"""
The content endpoint (/search) returns
all pieces of content in the API.
"""
import requests
import copy


class Content:

    def __init__(self, api, url=None, **kwargs):
        """
        :param api: api_key
        :param url: optional url to get the content.
        :param kwargs: optional header data
        :return: None
        """

        self.__headers = {
            "api-key": api,
            "format": "json"
        }
        self.__request_response = None

        if url is None:
            self.base_url = "https://content.guardianapis.com/search"
        else:
            self.base_url = url

        if kwargs:
            for key, value in kwargs.items():
                self.__headers[key] = value

    def __response(self, headers=None):

        """
        :param headers: optional header
        :return: returns raw response.
        """

        if headers is None:
            headers = self.__headers
        else:
            headers.update(self.__headers)

        res = requests.get(self.base_url, headers)

        return res

    def get_request_response(self, headers=None):

        """
        :param headers: optional headers
        :return: raw request response
        """

        self.__request_response = self.__response(headers)
        return self.__request_response

    def get_content_response(self, headers=None):

        """
        :param headers: optional header
        :return: json content of the response for the request
        """

        self.get_request_response(headers)
        return self.__request_response.json()

    def response_headers(self, headers=None):

        """
        :param headers: optional header
        :return: dict of header contents in the response
        """

        if self.__request_response:
            response_content = copy.deepcopy(self.__request_response.json())
        else:
            self.get_request_response(headers)
            response_content = copy.deepcopy(self.__request_response.json())

        headers_content = response_content['response']
        headers_content.pop("results")

        return headers_content

    def find_by_id(self, ids, **kwargs):

        """
        :param ids: Get the Content using its id. IDs are usually in the form
        of url/section/YYYY/month/DD/name-of-article/
        technology/2014/feb/17/flappy-bird-clones-apple-google

        :param kwargs: optional headers
        :return: dict
        """

        ids_and_options = self.__response_for_id(ids, **kwargs)
        ids_and_options.update(self.__headers)

        return self.__response(ids_and_options).json()

    @staticmethod
    def __response_for_id(ids, **kwargs):

        """
        :param ids: IDs are usually in the form
        of url/section/YYYY/month/DD/name-of-article/

        :param kwargs: optional headers
        :return: dict
        """

        headers = {}

        if ids and isinstance(ids, str):
            headers["ids"] = ids
        if kwargs:
            headers.update(kwargs)

        return headers

    @staticmethod
    def get_results(content):

        """
        :param content: response from url
        :return: list of results
        """

        if isinstance(content, dict):
            results = content["response"]["results"]
        else:
            raise TypeError("Content of type dictionary required as input.")

        return results if results else []

    def get_references_in_page(self, page_number=None):

        """
        :param page_number: optional
        :return:
        """

        head = self.response_headers()

        if page_number is None:
            content = self.get_content_response({
                "show-references": "all"
            })
            results = self.get_results(content)
            references = self.__get_references(results)
            return references
        elif page_number and page_number <= head["pages"]:
            content = self.get_content_response({
                "page": page_number,
                "show-references": "all"
            })
            results = self.get_results(content)
            references = self.__get_references(results)
            return references
        else:
            raise ValueError("Page number greater than available pages. Available pages {}."
                             .format(head["pages"]))

    @staticmethod
    def __get_references(results):

        """
        :param results: list of results
        :return: list of results
        """

        refs = [(result["id"], result["references"]) for result in results if result["references"]]

        return refs

# %%
# create content
headers = {
    "page-size": 5,
    "order-by": "newest",
}
content = theguardian_content.Content(api='test', **headers)

# looping through pages
response_headers = content.response_headers()
total_pages = response_headers["pages"]

# print apiUrls for all the results in first 5 pages
required_pages = 5
required_urls = []

if total_pages > required_pages:

    headers = {
        "page-size": 5,
        "order-by": "newest",
    }
    content2 = theguardian_content.Content(api='test', **headers)

    for page in range(1, required_pages+1):
        res = content2.get_content_response(headers={"page": page})
        page_results = res['response']['results']
        for result in page_results:
            required_urls.append(result["apiUrl"])

for url in required_urls:
    print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3842bfd8f245> in <cell line: 0>()
#       4     "order-by": "newest",
#       5 }
# ----> 6 content = theguardian_content.Content(api='test', **headers)
#       7
#       8 # looping through pages
#
# NameError: name 'theguardian_content' is not defined

# %%
"""
The content endpoint (/search) returns
all pieces of content in the API.
"""
import requests
import copy


class Content:

    def __init__(self, api, url=None, **kwargs):
        """
        :param api: api_key
        :param url: optional url to get the content.
        :param kwargs: optional header data
        :return: None
        """

        self.__headers = {
            "api-key": api,
            "format": "json"
        }
        self.__request_response = None

        if url is None:
            self.base_url = "https://content.guardianapis.com/search"
        else:
            self.base_url = url

        if kwargs:
            for key, value in kwargs.items():
                self.__headers[key] = value

    def __response(self, headers=None):

        """
        :param headers: optional header
        :return: returns raw response.
        """

        if headers is None:
            headers = self.__headers
        else:
            headers.update(self.__headers)

        res = requests.get(self.base_url, headers)

        return res

    def get_request_response(self, headers=None):

        """
        :param headers: optional headers
        :return: raw request response
        """

        self.__request_response = self.__response(headers)
        return self.__request_response

    def get_content_response(self, headers=None):

        """
        :param headers: optional header
        :return: json content of the response for the request
        """

        self.get_request_response(headers)
        return self.__request_response.json()

    def response_headers(self, headers=None):

        """
        :param headers: optional header
        :return: dict of header contents in the response
        """

        if self.__request_response:
            response_content = copy.deepcopy(self.__request_response.json())
        else:
            self.get_request_response(headers)
            response_content = copy.deepcopy(self.__request_response.json())

        headers_content = response_content['response']
        headers_content.pop("results")

        return headers_content

    def find_by_id(self, ids, **kwargs):

        """
        :param ids: Get the Content using its id. IDs are usually in the form
        of url/section/YYYY/month/DD/name-of-article/
        technology/2014/feb/17/flappy-bird-clones-apple-google

        :param kwargs: optional headers
        :return: dict
        """

        ids_and_options = self.__response_for_id(ids, **kwargs)
        ids_and_options.update(self.__headers)

        return self.__response(ids_and_options).json()

    @staticmethod
    def __response_for_id(ids, **kwargs):

        """
        :param ids: IDs are usually in the form
        of url/section/YYYY/month/DD/name-of-article/

        :param kwargs: optional headers
        :return: dict
        """

        headers = {}

        if ids and isinstance(ids, str):
            headers["ids"] = ids
        if kwargs:
            headers.update(kwargs)

        return headers

    @staticmethod
    def get_results(content):

        """
        :param content: response from url
        :return: list of results
        """

        if isinstance(content, dict):
            results = content["response"]["results"]
        else:
            raise TypeError("Content of type dictionary required as input.")

        return results if results else []

    def get_references_in_page(self, page_number=None):

        """
        :param page_number: optional
        :return:
        """

        head = self.response_headers()

        if page_number is None:
            content = self.get_content_response({
                "show-references": "all"
            })
            results = self.get_results(content)
            references = self.__get_references(results)
            return references
        elif page_number and page_number <= head["pages"]:
            content = self.get_content_response({
                "page": page_number,
                "show-references": "all"
            })
            results = self.get_results(content)
            references = self.__get_references(results)
            return references
        else:
            raise ValueError("Page number greater than available pages. Available pages {}."
                             .format(head["pages"]))

    @staticmethod
    def __get_references(results):

        """
        :param results: list of results
        :return: list of results
        """

        refs = [(result["id"], result["references"]) for result in results if result["references"]]

        return refs

# %%
"""
The edition endpoint returns all editions in the API.
"""
from theguardian import theguardian_section


class Edition(theguardian_section.Section):

    def __init__(self, api, **kwargs):

        """
        :param api: api-key
        :param kwargs: optional headers
        :return:
        """
        base_url = "https://content.guardianapis.com/editions"
        super(Edition, self).__init__(api, base_url, **kwargs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-883a228954af> in <cell line: 0>()
#       2 The edition endpoint returns all editions in the API.
#       3 """
# ----> 4 from theguardian import theguardian_section
#       5
#       6
#
# ModuleNotFoundError: No module named 'theguardian'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
"""
This example deals with returning content of section.
"""
from theguardian import theguardian_section
from theguardian import theguardian_content


# get the sports sections
headers = {"q": "israel"}  # q=query parameter/search parameter
section = theguardian_section.Section(api='e0e11527-a292-4f44-ae54-44e05c6f72fc', **headers)

# get the results
section_content = section.get_content_response()
results = section.get_results(section_content)

# get different editions from the results
editions = results[0]['editions']

# get uk/sports edition apiUrl
uk_sports = [edi["apiUrl"] for edi in editions if edi["id"] == "uk/sport"][0]

# use this api url to sports content
content = theguardian_content.Content(api='test', url=uk_sports)

# get section response
content_response = content.get_content_response()
print(content_response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-779599fa6c22> in <cell line: 0>()
#       2 This example deals with returning content of section.
#       3 """
# ----> 4 from theguardian import theguardian_section
#       5 from theguardian import theguardian_content
#       6
#
# ModuleNotFoundError: No module named 'theguardian'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
